# %%
import xgboost as xgb
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

# %%
features = pd.read_csv('CreacionDeFeatures/trainingSet.csv')
testing = pd.read_csv('CreacionDeFeatures/testingSet.csv')

labels = pd.read_csv('CreacionDeFeatures/Data/labels_training_set.csv')

# %%
labels.sum()
# Out:
# person    0566e9c16ec7ee77abe7a2fb3472836487ed62dedb2c4d...
# label                                                   980
# dtype: object

# %%
labels.count()
# Out:
# person    19414
# label     19414
# dtype: int64

# %%
balance = 19414/980

balance
# Out:
# 19.81020408163265

# %%
features = features.set_index('person')

features.head()
# Out:
#           CantidadEventos  CantidadCompras  CantidadLeads  VentasHaceUnMes  \
# person
# 0008ed71                6              0.0            0.0              0.0
# 000c79fe               17              0.0            0.0              0.0
# 001802e4               19              0.0            0.0              0.0
# 0019e639              471              2.0            0.0              1.0
# 001b0bf9                7              1.0            0.0              1.0
#
#           LeadsHaceUnMes  VentasHaceDosMeses  LeadsHaceDosMeses  \
# person
# 0008ed71             0.0                 0.0                0.0
# 000c79fe             0.0                 0.0                0.0
# 001802e4             0.0                 0.0                0.0
# 0019e639             0.0                 1.0                0.0
# 001b0bf9             0.0                 1.0                0.0
#
#           CantidadCheckouts  VentasMes1  VentasMes2     ...      \
# person                                                  ...
# 0008ed71                3.0         0.0         0.0     ...
# 000c79fe                1.0         0.0         0.0     ...
# 001802e4                1.0         0.0         0.0     ...
# 0019e639               15.0         0.0         1.0     ...
# 001b0bf9                2.0         0.0         0.0     ...
#
#           EntraronConComputadora  EntraronConSmartphone  EntraronConTablet  \
# person
# 0008ed71                     1.0                    0.0                0.0
# 000c79fe                     0.0                    1.0                0.0
# 001802e4                     0.0                    1.0                0.0
# 0019e639                     1.0                    0.0                0.0
# 001b0bf9                     0.0                    0.0                0.0
#
#           CantidadAdHits  DiasDesdeUltimoAdHit  DiasDesdeUltimaBusqueda  \
# person
# 0008ed71             0.0                1000.0                   1000.0
# 000c79fe             1.0                   3.0                      3.0
# 001802e4             5.0                   1.0                      1.0
# 0019e639            29.0                  10.0                     10.0
# 001b0bf9             0.0                1000.0                   1000.0
#
#           CantidadDeColoresVistos  CantidadDiasDiferentesDeVisita  \
# person
# 0008ed71                        3                               1
# 000c79fe                        1                               1
# 001802e4                        2                               1
# 0019e639                       14                              14
# 001b0bf9                        2                               1
#
#           CantidadDeModelosVistos  EsDeBrazil
# person
# 0008ed71                        3         1.0
# 000c79fe                        1         1.0
# 001802e4                        2         1.0
# 0019e639                       26         1.0
# 001b0bf9                        1         0.0
#
# [5 rows x 29 columns]

# %%
labels = labels.set_index('person')

labels.head()
# Out:
#           label
# person
# 0566e9c1      0
# 6ec7ee77      0
# abe7a2fb      0
# 34728364      0
# 87ed62de      0

# %%
data = features.merge(labels, left_index=True, right_index=True)

data.head()
# Out:
#           CantidadEventos  CantidadCompras  CantidadLeads  VentasHaceUnMes  \
# person
# 0008ed71                6              0.0            0.0              0.0
# 000c79fe               17              0.0            0.0              0.0
# 001802e4               19              0.0            0.0              0.0
# 0019e639              471              2.0            0.0              1.0
# 001b0bf9                7              1.0            0.0              1.0
#
#           LeadsHaceUnMes  VentasHaceDosMeses  LeadsHaceDosMeses  \
# person
# 0008ed71             0.0                 0.0                0.0
# 000c79fe             0.0                 0.0                0.0
# 001802e4             0.0                 0.0                0.0
# 0019e639             0.0                 1.0                0.0
# 001b0bf9             0.0                 1.0                0.0
#
#           CantidadCheckouts  VentasMes1  VentasMes2  ...    \
# person                                               ...
# 0008ed71                3.0         0.0         0.0  ...
# 000c79fe                1.0         0.0         0.0  ...
# 001802e4                1.0         0.0         0.0  ...
# 0019e639               15.0         0.0         1.0  ...
# 001b0bf9                2.0         0.0         0.0  ...
#
#           EntraronConSmartphone  EntraronConTablet  CantidadAdHits  \
# person
# 0008ed71                    0.0                0.0             0.0
# 000c79fe                    1.0                0.0             1.0
# 001802e4                    1.0                0.0             5.0
# 0019e639                    0.0                0.0            29.0
# 001b0bf9                    0.0                0.0             0.0
#
#           DiasDesdeUltimoAdHit  DiasDesdeUltimaBusqueda  \
# person
# 0008ed71                1000.0                   1000.0
# 000c79fe                   3.0                      3.0
# 001802e4                   1.0                      1.0
# 0019e639                  10.0                     10.0
# 001b0bf9                1000.0                   1000.0
#
#           CantidadDeColoresVistos  CantidadDiasDiferentesDeVisita  \
# person
# 0008ed71                        3                               1
# 000c79fe                        1                               1
# 001802e4                        2                               1
# 0019e639                       14                              14
# 001b0bf9                        2                               1
#
#           CantidadDeModelosVistos  EsDeBrazil  label
# person
# 0008ed71                        3         1.0      0
# 000c79fe                        1         1.0      0
# 001802e4                        2         1.0      0
# 0019e639                       26         1.0      0
# 001b0bf9                        1         0.0      0
#
# [5 rows x 30 columns]

# %%
features, labels = data.iloc[:,:-1],data.iloc[:,-1]

# %%
features.head()
# Out:
#           CantidadEventos  CantidadCompras  CantidadLeads  VentasHaceUnMes  \
# person
# 0008ed71                6              0.0            0.0              0.0
# 000c79fe               17              0.0            0.0              0.0
# 001802e4               19              0.0            0.0              0.0
# 0019e639              471              2.0            0.0              1.0
# 001b0bf9                7              1.0            0.0              1.0
#
#           LeadsHaceUnMes  VentasHaceDosMeses  LeadsHaceDosMeses  \
# person
# 0008ed71             0.0                 0.0                0.0
# 000c79fe             0.0                 0.0                0.0
# 001802e4             0.0                 0.0                0.0
# 0019e639             0.0                 1.0                0.0
# 001b0bf9             0.0                 1.0                0.0
#
#           CantidadCheckouts  VentasMes1  VentasMes2     ...      \
# person                                                  ...
# 0008ed71                3.0         0.0         0.0     ...
# 000c79fe                1.0         0.0         0.0     ...
# 001802e4                1.0         0.0         0.0     ...
# 0019e639               15.0         0.0         1.0     ...
# 001b0bf9                2.0         0.0         0.0     ...
#
#           EntraronConComputadora  EntraronConSmartphone  EntraronConTablet  \
# person
# 0008ed71                     1.0                    0.0                0.0
# 000c79fe                     0.0                    1.0                0.0
# 001802e4                     0.0                    1.0                0.0
# 0019e639                     1.0                    0.0                0.0
# 001b0bf9                     0.0                    0.0                0.0
#
#           CantidadAdHits  DiasDesdeUltimoAdHit  DiasDesdeUltimaBusqueda  \
# person
# 0008ed71             0.0                1000.0                   1000.0
# 000c79fe             1.0                   3.0                      3.0
# 001802e4             5.0                   1.0                      1.0
# 0019e639            29.0                  10.0                     10.0
# 001b0bf9             0.0                1000.0                   1000.0
#
#           CantidadDeColoresVistos  CantidadDiasDiferentesDeVisita  \
# person
# 0008ed71                        3                               1
# 000c79fe                        1                               1
# 001802e4                        2                               1
# 0019e639                       14                              14
# 001b0bf9                        2                               1
#
#           CantidadDeModelosVistos  EsDeBrazil
# person
# 0008ed71                        3         1.0
# 000c79fe                        1         1.0
# 001802e4                        2         1.0
# 0019e639                       26         1.0
# 001b0bf9                        1         0.0
#
# [5 rows x 29 columns]

# %%
labels.head()

#Estan en el mismo orden
# Out:
# person
# 0008ed71    0
# 000c79fe    0
# 001802e4    0
# 0019e639    0
# 001b0bf9    0
# Name: label, dtype: int64

# %%
data_dmatrix = xgb.DMatrix(data=features,label=labels)

# %%
features_train, features_test, labels_train, labels_test = \
    train_test_split(features, labels, test_size=0.3, random_state=123)

# %%
xg_reg = xgb.XGBClassifier(objective ='binary:logistic', 
                colsample_bytree = 0.8, learning_rate = 0.02,
                max_depth = 3, alpha = 3, gamma = 0.5, n_estimators = 300,
                min_child_weight = 45, subsample = 0.6, scale_pos_weight=balance)

# %%
xg_reg.fit(features_train,labels_train)
# Out:
# XGBClassifier(alpha=3, base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=0.8, gamma=0.5, learning_rate=0.02,
#        max_delta_step=0, max_depth=3, min_child_weight=45, missing=None,
#        n_estimators=300, n_jobs=1, nthread=None,
#        objective='binary:logistic', random_state=0, reg_alpha=0,
#        reg_lambda=1, scale_pos_weight=19.81020408163265, seed=None,
#        silent=True, subsample=0.6)

# %%
labels_preds = xg_reg.predict(features_test)

# %%
from sklearn.metrics import accuracy_score
accuracy = accuracy_score(labels_test, labels_preds)
accuracy
# Out:
# 0.7780257510729613

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(labels_test, labels_preds)
# C0,0  True Negatives,  response 0, predicted 0
# C1,0  False Negatives, response 1, predicted 0
# C0,1  False Positives, response 0, predicted 1
# C1,1  True Positives,  response 1, predicted 1
# Out:
# array([[4282, 1245],
#        [  48,  250]], dtype=int64)

# %%
labels_preds.sum()
# Out:
# 1495

# %%
labels_test.sum()
# Out:
# 298

# %%
labels_test.count()
# Out:
# 5825

# %%
xg_class = xgb.XGBClassifier(objective ='binary:logistic', 
                colsample_bytree = 0.9, learning_rate = 0.02,
                max_depth = 4, alpha = 16, gamma = 0.8, n_estimators = 350,
                min_child_weight = 40, subsample = 0.5, scale_pos_weight=balance)

# %%
testing = testing.set_index('person')

# %%
xg_class.fit(features,labels)
# Out:
# XGBClassifier(alpha=16, base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=0.9, gamma=0.8, learning_rate=0.02,
#        max_delta_step=0, max_depth=4, min_child_weight=40, missing=None,
#        n_estimators=350, n_jobs=1, nthread=None,
#        objective='binary:logistic', random_state=0, reg_alpha=0,
#        reg_lambda=1, scale_pos_weight=19.81020408163265, seed=None,
#        silent=True, subsample=0.5)

# %%
labels_predicciones = xg_class.predict(testing)

# %%
labels_predicciones.sum()
# Out:
# 4836

# %%
print(labels_predicciones)
# Out:
# [0 1 0 ... 1 1 0]

# %%
sample = pd.read_csv('CreacionDeFeatures/Data/trocafone_kaggle_submit_sample_all_0.csv')

# %%
sample = sample.set_index('person')

sample.head()
# Out:
#           label
# person
# 4886f805      0
# 0297fc1e      0
# 2d681dd8      0
# cccea85e      0
# 4c8a8b93      0

# %%
sample = sample.sort_index()

sample.head()
# Out:
#           label
# person
# 00091926      0
# 00091a7a      0
# 000ba417      0
# 000e4d9e      0
# 000e619d      0

# %%
testing.head()

#Estan en el mismo orden
# Out:
#           CantidadEventos  CantidadCompras  CantidadLeads  VentasHaceUnMes  \
# person
# 00091926              448              0.0            0.0              0.0
# 00091a7a               10              0.0            0.0              0.0
# 000ba417              206              1.0            0.0              1.0
# 000e4d9e              411              0.0            0.0              0.0
# 000e619d               68              0.0            0.0              0.0
#
#           LeadsHaceUnMes  VentasHaceDosMeses  LeadsHaceDosMeses  \
# person
# 00091926             0.0                 0.0                0.0
# 00091a7a             0.0                 0.0                0.0
# 000ba417             0.0                 1.0                0.0
# 000e4d9e             0.0                 0.0                0.0
# 000e619d             0.0                 0.0                0.0
#
#           CantidadCheckouts  VentasMes1  VentasMes2     ...      \
# person                                                  ...
# 00091926                2.0         0.0         0.0     ...
# 00091a7a                0.0         0.0         0.0     ...
# 000ba417                6.0         0.0         0.0     ...
# 000e4d9e                1.0         0.0         0.0     ...
# 000e619d                1.0         0.0         0.0     ...
#
#           EntraronConComputadora  EntraronConSmartphone  EntraronConTablet  \
# person
# 00091926                     1.0                    0.0                0.0
# 00091a7a                     0.0                    1.0                0.0
# 000ba417                     1.0                    0.0                0.0
# 000e4d9e                     1.0                    0.0                0.0
# 000e619d                     1.0                    0.0                0.0
#
#           CantidadAdHits  DiasDesdeUltimoAdHit  DiasDesdeUltimaBusqueda  \
# person
# 00091926            15.0                   1.0                   1000.0
# 00091a7a             1.0                  67.0                   1000.0
# 000ba417             1.0                  15.0                   1000.0
# 000e4d9e            19.0                  10.0                   1000.0
# 000e619d             6.0                  14.0                     14.0
#
#           CantidadDeColoresVistos  CantidadDiasDiferentesDeVisita  \
# person
# 00091926                       20                              22
# 00091a7a                        3                               1
# 000ba417                       20                               3
# 000e4d9e                       12                               9
# 000e619d                        9                               4
#
#           CantidadDeModelosVistos  EsDeBrazil
# person
# 00091926                       36         1.0
# 00091a7a                        3         1.0
# 000ba417                       26         1.0
# 000e4d9e                       37         1.0
# 000e619d                       23         1.0
#
# [5 rows x 29 columns]

# %%
sample['label'] = labels_predicciones

sample.head()
# Out:
#           label
# person
# 00091926      0
# 00091a7a      1
# 000ba417      0
# 000e4d9e      0
# 000e619d      0

# %%
sample.to_csv('predicciones.csv')

# %%
xgb.plot_importance(xg_class)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-105-d41cb3891f2f> in <module>
#       1 xgb.plot_importance(xg_class)
# ----> 2 pyplot.show()
#
# NameError: name 'pyplot' is not defined
