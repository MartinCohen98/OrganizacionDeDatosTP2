# %%
import pandas as pd
import numpy as np
import datetime

# %%
logsTrocafone = pd.read_csv('Data/events_up_to_01062018.csv', low_memory = False)

trainingSet = pd.read_csv('trainingSet.csv')
trainingSet = trainingSet.set_index('person')

testingSet = pd.read_csv('testingSet.csv')
testingSet = testingSet.set_index('person')

trainingSet.head()
# Out:
#           CantidadEventos  CantidadCompras  CantidadLeads  VentasHaceUnMes  \
# person
# 0008ed71                6              0.0            0.0              0.0
# 000c79fe               17              0.0            0.0              0.0
# 001802e4               19              0.0            0.0              0.0
# 0019e639              471              2.0            0.0              1.0
# 001b0bf9                7              1.0            0.0              1.0
#
#           LeadsHaceUnMes  VentasHaceDosMeses  LeadsHaceDosMeses  \
# person
# 0008ed71             0.0                 0.0                0.0
# 000c79fe             0.0                 0.0                0.0
# 001802e4             0.0                 0.0                0.0
# 0019e639             0.0                 1.0                0.0
# 001b0bf9             0.0                 1.0                0.0
#
#           CantidadCheckouts  VentasMes1  VentasMes2          ...           \
# person                                                       ...
# 0008ed71                3.0         0.0         0.0          ...
# 000c79fe                1.0         0.0         0.0          ...
# 001802e4                1.0         0.0         0.0          ...
# 0019e639               15.0         0.0         1.0          ...
# 001b0bf9                2.0         0.0         0.0          ...
#
#           DiasDesdePrimerEvento  DiasDesdeUltimaConversion  \
# person
# 0008ed71                   15.0                    10000.0
# 000c79fe                    3.0                    10000.0
# 001802e4                    1.0                    10000.0
# 0019e639                  124.0                       10.0
# 001b0bf9                   10.0                       10.0
#
#           CantidadSearchEngineHits  EntraronMasDeUnaVez  \
# person
# 0008ed71                       0.0                  1.0
# 000c79fe                       1.0                  0.0
# 001802e4                       0.0                  0.0
# 0019e639                      13.0                  1.0
# 001b0bf9                       0.0                  0.0
#
#           DiasDesdeUltimoCheckout  EntraronConComputadora  \
# person
# 0008ed71                     15.0                     1.0
# 000c79fe                      3.0                     0.0
# 001802e4                      1.0                     0.0
# 0019e639                     10.0                     1.0
# 001b0bf9                     10.0                     0.0
#
#           EntraronConSmartphone  EntraronConTablet  CantidadAdHits  \
# person
# 0008ed71                    0.0                0.0             0.0
# 000c79fe                    1.0                0.0             1.0
# 001802e4                    1.0                0.0             5.0
# 0019e639                    0.0                0.0            29.0
# 001b0bf9                    0.0                0.0             0.0
#
#           DiasDesdeUltimoAdHit
# person
# 0008ed71                1000.0
# 000c79fe                   3.0
# 001802e4                   1.0
# 0019e639                  10.0
# 001b0bf9                1000.0
#
# [5 rows x 24 columns]

# %%
logsTrocafone['timestamp'] = pd.to_datetime(logsTrocafone['timestamp'], errors = 'coerce')
logsTrocafone.head()
# Out:
#             timestamp           event    person  url      sku  \
# 0 2018-05-18 00:11:59  viewed product  4886f805  NaN   9288.0
# 1 2018-05-18 00:11:27  viewed product  ad93850f  NaN    304.0
# 2 2018-05-18 00:11:16  viewed product  0297fc1e  NaN   6888.0
# 3 2018-05-18 00:11:14  viewed product  2d681dd8  NaN  11890.0
# 4 2018-05-18 00:11:09  viewed product  cccea85e  NaN   7517.0
#
#                      model  condition storage           color skus  \
# 0  Samsung Galaxy J7 Prime  Excelente    32GB         Dourado  NaN
# 1                iPhone 5s  Muito Bom    32GB  Cinza espacial  NaN
# 2                iPhone 6S  Muito Bom    64GB        Prateado  NaN
# 3                 iPhone 7        Bom   128GB        Vermelho  NaN
# 4              LG G4 H818P  Excelente    32GB          Branco  NaN
#
#         ...       search_engine channel new_vs_returning city region country  \
# 0       ...                 NaN     NaN              NaN  NaN    NaN     NaN
# 1       ...                 NaN     NaN              NaN  NaN    NaN     NaN
# 2       ...                 NaN     NaN              NaN  NaN    NaN     NaN
# 3       ...                 NaN     NaN              NaN  NaN    NaN     NaN
# 4       ...                 NaN     NaN              NaN  NaN    NaN     NaN
#
#   device_type screen_resolution operating_system_version browser_version
# 0         NaN               NaN                      NaN             NaN
# 1         NaN               NaN                      NaN             NaN
# 2         NaN               NaN                      NaN             NaN
# 3         NaN               NaN                      NaN             NaN
# 4         NaN               NaN                      NaN             NaN
#
# [5 rows x 23 columns]

# %%
logsTrocafone['timestamp'] = logsTrocafone['timestamp'].dt.date

logsTrocafone.head()
# Out:
#     timestamp           event    person  url      sku  \
# 0  2018-05-18  viewed product  4886f805  NaN   9288.0
# 1  2018-05-18  viewed product  ad93850f  NaN    304.0
# 2  2018-05-18  viewed product  0297fc1e  NaN   6888.0
# 3  2018-05-18  viewed product  2d681dd8  NaN  11890.0
# 4  2018-05-18  viewed product  cccea85e  NaN   7517.0
#
#                      model  condition storage           color skus  \
# 0  Samsung Galaxy J7 Prime  Excelente    32GB         Dourado  NaN
# 1                iPhone 5s  Muito Bom    32GB  Cinza espacial  NaN
# 2                iPhone 6S  Muito Bom    64GB        Prateado  NaN
# 3                 iPhone 7        Bom   128GB        Vermelho  NaN
# 4              LG G4 H818P  Excelente    32GB          Branco  NaN
#
#         ...       search_engine channel new_vs_returning city region country  \
# 0       ...                 NaN     NaN              NaN  NaN    NaN     NaN
# 1       ...                 NaN     NaN              NaN  NaN    NaN     NaN
# 2       ...                 NaN     NaN              NaN  NaN    NaN     NaN
# 3       ...                 NaN     NaN              NaN  NaN    NaN     NaN
# 4       ...                 NaN     NaN              NaN  NaN    NaN     NaN
#
#   device_type screen_resolution operating_system_version browser_version
# 0         NaN               NaN                      NaN             NaN
# 1         NaN               NaN                      NaN             NaN
# 2         NaN               NaN                      NaN             NaN
# 3         NaN               NaN                      NaN             NaN
# 4         NaN               NaN                      NaN             NaN
#
# [5 rows x 23 columns]

# %%
busquedas = logsTrocafone.loc[logsTrocafone['event'] == 'searched products', :]

busquedas.head()
# Out:
#      timestamp              event    person  url  sku model condition storage  \
# 5   2018-05-18  searched products  4c8a8b93  NaN  NaN   NaN       NaN     NaN
# 18  2018-05-18  searched products  29ebb414  NaN  NaN   NaN       NaN     NaN
# 29  2018-05-18  searched products  15ea8012  NaN  NaN   NaN       NaN     NaN
# 35  2018-05-18  searched products  d21b8e6b  NaN  NaN   NaN       NaN     NaN
# 39  2018-05-18  searched products  d21b8e6b  NaN  NaN   NaN       NaN     NaN
#
#    color                                               skus       ...        \
# 5    NaN  10240,9987,10322,10085,9944,9931,13404,10154,1...       ...
# 18   NaN  3371,6357,6371,3191,2718,6001,2777,6248,2725,8...       ...
# 29   NaN                                  12786,12800,12772       ...
# 35   NaN  5016,5088,8397,8429,10728,5075,7631,9216,4969,...       ...
# 39   NaN                            12520,12507,12548,12534       ...
#
#    search_engine channel new_vs_returning city region country device_type  \
# 5            NaN     NaN              NaN  NaN    NaN     NaN         NaN
# 18           NaN     NaN              NaN  NaN    NaN     NaN         NaN
# 29           NaN     NaN              NaN  NaN    NaN     NaN         NaN
# 35           NaN     NaN              NaN  NaN    NaN     NaN         NaN
# 39           NaN     NaN              NaN  NaN    NaN     NaN         NaN
#
#    screen_resolution operating_system_version browser_version
# 5                NaN                      NaN             NaN
# 18               NaN                      NaN             NaN
# 29               NaN                      NaN             NaN
# 35               NaN                      NaN             NaN
# 39               NaN                      NaN             NaN
#
# [5 rows x 23 columns]

# %%
ultimoEventoPorPersona = busquedas.groupby('person').agg({'timestamp':'max'})

ultimoEventoPorPersona.head()
# Out:
#            timestamp
# person
# 000c79fe  2018-05-29
# 000e619d  2018-05-18
# 001001be  2018-05-16
# 001802e4  2018-05-31
# 0019e639  2018-05-22

# %%
ultimoEventoPorPersona['timestamp'] =  datetime.date(2018, 6, 1) - ultimoEventoPorPersona['timestamp']

ultimoEventoPorPersona['timestamp'].head()
# Out:
# person
# 000c79fe    3 days
# 000e619d   14 days
# 001001be   16 days
# 001802e4    1 days
# 0019e639   10 days
# Name: timestamp, dtype: timedelta64[ns]

# %%
ultimoEventoPorPersona['timestamp'] = ultimoEventoPorPersona['timestamp'] / np.timedelta64(1, 'D')

ultimoEventoPorPersona.head()
# Out:
#           timestamp
# person
# 000c79fe        3.0
# 000e619d       14.0
# 001001be       16.0
# 001802e4        1.0
# 0019e639       10.0

# %%
nuevoTrainingSet = trainingSet.merge(ultimoEventoPorPersona, how='left', left_index=True, right_index=True)

nuevoTrainingSet.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 19414 entries, 0008ed71 to fff78145
# Data columns (total 25 columns):
# CantidadEventos              19414 non-null int64
# CantidadCompras              19414 non-null float64
# CantidadLeads                19414 non-null float64
# VentasHaceUnMes              19414 non-null float64
# LeadsHaceUnMes               19414 non-null float64
# VentasHaceDosMeses           19414 non-null float64
# LeadsHaceDosMeses            19414 non-null float64
# CantidadCheckouts            19414 non-null float64
# VentasMes1                   19414 non-null float64
# VentasMes2                   19414 non-null float64
# VentasMes3                   19414 non-null float64
# VentasMes4                   19414 non-null float64
# PromedioVentasPorMes         19414 non-null float64
# DiasDesdeUltimoEvento        19414 non-null float64
# DiasDesdePrimerEvento        19414 non-null float64
# DiasDesdeUltimaConversion    19414 non-null float64
# CantidadSearchEngineHits     19414 non-null float64
# EntraronMasDeUnaVez          19414 non-null float64
# DiasDesdeUltimoCheckout      19414 non-null float64
# EntraronConComputadora       19414 non-null float64
# EntraronConSmartphone        19414 non-null float64
# EntraronConTablet            19414 non-null float64
# CantidadAdHits               19414 non-null float64
# DiasDesdeUltimoAdHit         19414 non-null float64
# timestamp                    6519 non-null float64
# dtypes: float64(24), int64(1)
# memory usage: 4.5+ MB

# %%
nuevoTestingSet = testingSet.merge(ultimoEventoPorPersona, how='left', left_index=True, right_index=True)

nuevoTestingSet.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 19415 entries, 00091926 to fffd1246
# Data columns (total 25 columns):
# CantidadEventos              19415 non-null int64
# CantidadCompras              19415 non-null float64
# CantidadLeads                19415 non-null float64
# VentasHaceUnMes              19415 non-null float64
# LeadsHaceUnMes               19415 non-null float64
# VentasHaceDosMeses           19415 non-null float64
# LeadsHaceDosMeses            19415 non-null float64
# CantidadCheckouts            19415 non-null float64
# VentasMes1                   19415 non-null float64
# VentasMes2                   19415 non-null float64
# VentasMes3                   19415 non-null float64
# VentasMes4                   19415 non-null float64
# PromedioVentasPorMes         19415 non-null float64
# DiasDesdeUltimoEvento        19415 non-null float64
# DiasDesdePrimerEvento        19415 non-null float64
# DiasDesdeUltimaConversion    19415 non-null float64
# CantidadSearchEngineHits     19415 non-null float64
# EntraronMasDeUnaVez          19415 non-null float64
# DiasDesdeUltimoCheckout      19415 non-null float64
# EntraronConComputadora       19415 non-null float64
# EntraronConSmartphone        19415 non-null float64
# EntraronConTablet            19415 non-null float64
# CantidadAdHits               19415 non-null float64
# DiasDesdeUltimoAdHit         19415 non-null float64
# timestamp                    6574 non-null float64
# dtypes: float64(24), int64(1)
# memory usage: 4.5+ MB

# %%
nuevoTrainingSet = nuevoTrainingSet.fillna(1000)

#Agrego un numero muy grande significando que na hacen un checkout hace mucho

nuevoTrainingSet.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 19414 entries, 0008ed71 to fff78145
# Data columns (total 25 columns):
# CantidadEventos              19414 non-null int64
# CantidadCompras              19414 non-null float64
# CantidadLeads                19414 non-null float64
# VentasHaceUnMes              19414 non-null float64
# LeadsHaceUnMes               19414 non-null float64
# VentasHaceDosMeses           19414 non-null float64
# LeadsHaceDosMeses            19414 non-null float64
# CantidadCheckouts            19414 non-null float64
# VentasMes1                   19414 non-null float64
# VentasMes2                   19414 non-null float64
# VentasMes3                   19414 non-null float64
# VentasMes4                   19414 non-null float64
# PromedioVentasPorMes         19414 non-null float64
# DiasDesdeUltimoEvento        19414 non-null float64
# DiasDesdePrimerEvento        19414 non-null float64
# DiasDesdeUltimaConversion    19414 non-null float64
# CantidadSearchEngineHits     19414 non-null float64
# EntraronMasDeUnaVez          19414 non-null float64
# DiasDesdeUltimoCheckout      19414 non-null float64
# EntraronConComputadora       19414 non-null float64
# EntraronConSmartphone        19414 non-null float64
# EntraronConTablet            19414 non-null float64
# CantidadAdHits               19414 non-null float64
# DiasDesdeUltimoAdHit         19414 non-null float64
# timestamp                    19414 non-null float64
# dtypes: float64(24), int64(1)
# memory usage: 4.5+ MB

# %%
nuevoTestingSet = nuevoTestingSet.fillna(1000)

#Agrego un numero muy grande significando que na hacen un checkout hace mucho

nuevoTestingSet.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 19415 entries, 00091926 to fffd1246
# Data columns (total 25 columns):
# CantidadEventos              19415 non-null int64
# CantidadCompras              19415 non-null float64
# CantidadLeads                19415 non-null float64
# VentasHaceUnMes              19415 non-null float64
# LeadsHaceUnMes               19415 non-null float64
# VentasHaceDosMeses           19415 non-null float64
# LeadsHaceDosMeses            19415 non-null float64
# CantidadCheckouts            19415 non-null float64
# VentasMes1                   19415 non-null float64
# VentasMes2                   19415 non-null float64
# VentasMes3                   19415 non-null float64
# VentasMes4                   19415 non-null float64
# PromedioVentasPorMes         19415 non-null float64
# DiasDesdeUltimoEvento        19415 non-null float64
# DiasDesdePrimerEvento        19415 non-null float64
# DiasDesdeUltimaConversion    19415 non-null float64
# CantidadSearchEngineHits     19415 non-null float64
# EntraronMasDeUnaVez          19415 non-null float64
# DiasDesdeUltimoCheckout      19415 non-null float64
# EntraronConComputadora       19415 non-null float64
# EntraronConSmartphone        19415 non-null float64
# EntraronConTablet            19415 non-null float64
# CantidadAdHits               19415 non-null float64
# DiasDesdeUltimoAdHit         19415 non-null float64
# timestamp                    19415 non-null float64
# dtypes: float64(24), int64(1)
# memory usage: 4.5+ MB

# %%
nuevoTrainingSet = nuevoTrainingSet.rename(columns={"timestamp": "DiasDesdeUltimaBusqueda"})

nuevoTrainingSet.head()
# Out:
#           CantidadEventos  CantidadCompras  CantidadLeads  VentasHaceUnMes  \
# person
# 0008ed71                6              0.0            0.0              0.0
# 000c79fe               17              0.0            0.0              0.0
# 001802e4               19              0.0            0.0              0.0
# 0019e639              471              2.0            0.0              1.0
# 001b0bf9                7              1.0            0.0              1.0
#
#           LeadsHaceUnMes  VentasHaceDosMeses  LeadsHaceDosMeses  \
# person
# 0008ed71             0.0                 0.0                0.0
# 000c79fe             0.0                 0.0                0.0
# 001802e4             0.0                 0.0                0.0
# 0019e639             0.0                 1.0                0.0
# 001b0bf9             0.0                 1.0                0.0
#
#           CantidadCheckouts  VentasMes1  VentasMes2           ...             \
# person                                                        ...
# 0008ed71                3.0         0.0         0.0           ...
# 000c79fe                1.0         0.0         0.0           ...
# 001802e4                1.0         0.0         0.0           ...
# 0019e639               15.0         0.0         1.0           ...
# 001b0bf9                2.0         0.0         0.0           ...
#
#           DiasDesdeUltimaConversion  CantidadSearchEngineHits  \
# person
# 0008ed71                    10000.0                       0.0
# 000c79fe                    10000.0                       1.0
# 001802e4                    10000.0                       0.0
# 0019e639                       10.0                      13.0
# 001b0bf9                       10.0                       0.0
#
#           EntraronMasDeUnaVez  DiasDesdeUltimoCheckout  \
# person
# 0008ed71                  1.0                     15.0
# 000c79fe                  0.0                      3.0
# 001802e4                  0.0                      1.0
# 0019e639                  1.0                     10.0
# 001b0bf9                  0.0                     10.0
#
#           EntraronConComputadora  EntraronConSmartphone  EntraronConTablet  \
# person
# 0008ed71                     1.0                    0.0                0.0
# 000c79fe                     0.0                    1.0                0.0
# 001802e4                     0.0                    1.0                0.0
# 0019e639                     1.0                    0.0                0.0
# 001b0bf9                     0.0                    0.0                0.0
#
#           CantidadAdHits  DiasDesdeUltimoAdHit  DiasDesdeUltimaBusqueda
# person
# 0008ed71             0.0                1000.0                   1000.0
# 000c79fe             1.0                   3.0                      3.0
# 001802e4             5.0                   1.0                      1.0
# 0019e639            29.0                  10.0                     10.0
# 001b0bf9             0.0                1000.0                   1000.0
#
# [5 rows x 25 columns]

# %%
nuevoTestingSet = nuevoTestingSet.rename(columns={"timestamp": "DiasDesdeUltimaBusqueda"})

nuevoTestingSet.head()
# Out:
#           CantidadEventos  CantidadCompras  CantidadLeads  VentasHaceUnMes  \
# person
# 00091926              448              0.0            0.0              0.0
# 00091a7a               10              0.0            0.0              0.0
# 000ba417              206              1.0            0.0              1.0
# 000e4d9e              411              0.0            0.0              0.0
# 000e619d               68              0.0            0.0              0.0
#
#           LeadsHaceUnMes  VentasHaceDosMeses  LeadsHaceDosMeses  \
# person
# 00091926             0.0                 0.0                0.0
# 00091a7a             0.0                 0.0                0.0
# 000ba417             0.0                 1.0                0.0
# 000e4d9e             0.0                 0.0                0.0
# 000e619d             0.0                 0.0                0.0
#
#           CantidadCheckouts  VentasMes1  VentasMes2           ...             \
# person                                                        ...
# 00091926                2.0         0.0         0.0           ...
# 00091a7a                0.0         0.0         0.0           ...
# 000ba417                6.0         0.0         0.0           ...
# 000e4d9e                1.0         0.0         0.0           ...
# 000e619d                1.0         0.0         0.0           ...
#
#           DiasDesdeUltimaConversion  CantidadSearchEngineHits  \
# person
# 00091926                    10000.0                       0.0
# 00091a7a                    10000.0                       0.0
# 000ba417                        6.0                       1.0
# 000e4d9e                    10000.0                       5.0
# 000e619d                    10000.0                       3.0
#
#           EntraronMasDeUnaVez  DiasDesdeUltimoCheckout  \
# person
# 00091926                  1.0                      6.0
# 00091a7a                  0.0                  10000.0
# 000ba417                  1.0                      6.0
# 000e4d9e                  1.0                     16.0
# 000e619d                  1.0                     15.0
#
#           EntraronConComputadora  EntraronConSmartphone  EntraronConTablet  \
# person
# 00091926                     1.0                    0.0                0.0
# 00091a7a                     0.0                    1.0                0.0
# 000ba417                     1.0                    0.0                0.0
# 000e4d9e                     1.0                    0.0                0.0
# 000e619d                     1.0                    0.0                0.0
#
#           CantidadAdHits  DiasDesdeUltimoAdHit  DiasDesdeUltimaBusqueda
# person
# 00091926            15.0                   1.0                   1000.0
# 00091a7a             1.0                  67.0                   1000.0
# 000ba417             1.0                  15.0                   1000.0
# 000e4d9e            19.0                  10.0                   1000.0
# 000e619d             6.0                  14.0                     14.0
#
# [5 rows x 25 columns]

# %%
#nuevoTrainingSet.to_csv('trainingSet.csv')
#Este comando reemplaza el training set existente con la feature agregada

# %%
#nuevoTestingSet.to_csv('testingSet.csv')
#Este comando reemplaza el testing set existente con la feature agregada
