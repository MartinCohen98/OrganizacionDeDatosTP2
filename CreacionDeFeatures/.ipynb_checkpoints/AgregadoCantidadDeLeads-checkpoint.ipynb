# %%
import pandas as pd
import numpy as np

# %%
logsTrocafone = pd.read_csv('Data/events_up_to_01062018.csv', low_memory = False)

trainingSet = pd.read_csv('trainingSet.csv')
trainingSet = trainingSet.set_index('person')

trainingSet.head()
# Out:
#           CantidadEventos  CantidadCompras
# person
# 0008ed71                6              0.0
# 000c79fe               17              0.0
# 001802e4               19              0.0
# 0019e639              471              2.0
# 001b0bf9                7              1.0

# %%
logsTrocafoneLeads = logsTrocafone.loc[logsTrocafone['event'] == 'lead', :]

logsTrocafoneLeads.head()
# Out:
#                    timestamp event    person  url  sku  \
# 2340698  2018-01-10 22:06:17  lead  cd739044  NaN  NaN
# 2340699  2018-04-18 01:14:10  lead  87dede0a  NaN  NaN
# 2340700  2018-04-18 02:45:58  lead  a6e1b6a0  NaN  NaN
# 2340701  2018-05-02 14:45:09  lead  e8683d4b  NaN  NaN
# 2340702  2018-01-23 17:12:29  lead  00546f4c  NaN  NaN
#
#                           model condition storage color skus       ...        \
# 2340698           iPhone 7 Plus       NaN     NaN   NaN  NaN       ...
# 2340699           iPhone 6 Plus       NaN     NaN   NaN  NaN       ...
# 2340700  Samsung Galaxy A3 Duos       NaN     NaN   NaN  NaN       ...
# 2340701                  LG K10       NaN     NaN   NaN  NaN       ...
# 2340702   Samsung Galaxy Note 5       NaN     NaN   NaN  NaN       ...
#
#         search_engine channel new_vs_returning city region country  \
# 2340698           NaN     NaN              NaN  NaN    NaN     NaN
# ...

# %%
cantidadDeLeads = logsTrocafoneCompras.groupby('person').agg({'event':'count'})

cantidadDeLeads.head()
# Out:
#           event
# person
# 00546f4c      1
# 016b86b9      1
# 01af6573      6
# 0297fc1e      1
# 029889eb      1

# %%
nuevoTrainingSet = trainingSet.merge(cantidadDeLeads, how='left', left_index=True, right_index=True)

nuevoTrainingSet.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 19414 entries, 0008ed71 to fff78145
# Data columns (total 3 columns):
# CantidadEventos    19414 non-null int64
# CantidadCompras    19414 non-null float64
# event              264 non-null float64
# dtypes: float64(2), int64(1)
# memory usage: 1.2+ MB

# %%
nuevoTrainingSet = nuevoTrainingSet.fillna(0)

nuevoTrainingSet.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 19414 entries, 0008ed71 to fff78145
# Data columns (total 3 columns):
# CantidadEventos    19414 non-null int64
# CantidadCompras    19414 non-null float64
# event              19414 non-null float64
# dtypes: float64(2), int64(1)
# memory usage: 1.2+ MB

# %%
nuevoTrainingSet.head()
# Out:
#           CantidadEventos  CantidadCompras  event
# person
# 0008ed71                6              0.0    0.0
# 000c79fe               17              0.0    0.0
# 001802e4               19              0.0    0.0
# 0019e639              471              2.0    0.0
# 001b0bf9                7              1.0    0.0

# %%
nuevoTrainingSet = nuevoTrainingSet.rename(columns={"event": "CantidadLeads"})

# %%
#nuevoTrainingSet.to_csv('trainingSet.csv')
#Este comando reemplaza el training set existente con la feature agregada
